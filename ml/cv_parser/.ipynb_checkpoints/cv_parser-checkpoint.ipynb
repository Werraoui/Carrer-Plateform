# %%
pip install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.14-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp310-cp310-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Using cached weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Using cached confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.24.2-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy) (2.2.6)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting pydantic<3.0.0,>=2.0.0 (from spacy)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: jinja2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy) (70.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: typing_extensions<5.0,>=4.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from confection<2.0.0,>=1.3.2->spacy) (4.15.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Downloading pydantic_core-2.46.3-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached charset_normalizer-3.4.7-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp310-cp310-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click>=8.2.1 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Using cached cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-7.6.0-py3-none-any.whl.metadata (25 kB)
# Collecting httpx>=0.24.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpcore==1.* (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting wrapt (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached wrapt-2.1.2-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.14-cp310-cp310-win_amd64.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/15.4 MB 10.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.4 MB 13.4 MB/s eta 0:00:01
#    ------------ --------------------------- 5.0/15.4 MB 9.1 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.4 MB 7.9 MB/s eta 0:00:02
#    --------------------- ------------------ 8.1/15.4 MB 8.0 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.4 MB 8.6 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.4 MB 7.2 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.4 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.4 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 6.8 MB/s  0:00:02
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp310-cp310-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp310-cp310-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp310-cp310-win_amd64.whl (121 kB)
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 14.5 MB/s  0:00:00
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.7-cp310-cp310-win_amd64.whl (159 kB)
# Using cached idna-3.13-py3-none-any.whl (68 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp310-cp310-win_amd64.whl (651 kB)
#    ---------------------------------------- 0.0/651.7 kB ? eta -:--:--
#    ---------------------------------------- 651.7/651.7 kB 12.6 MB/s  0:00:00
# Downloading thinc-8.3.13-cp310-cp310-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 12.3 MB/s  0:00:00
# Downloading blis-1.3.3-cp310-cp310-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.2 MB 13.1 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.2 MB 6.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 5.6 MB/s eta 0:00:01
#    --------------------------- ------------ 4.2/6.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 6.2 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typer-0.24.2-py3-none-any.whl (55 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-1.0.0-py3-none-any.whl (50 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Using cached cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.6.0-py3-none-any.whl (64 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached wrapt-2.1.2-cp310-cp310-win_amd64.whl (60 kB)
# Installing collected packages: wrapt, wasabi, urllib3, typing-inspection, tqdm, spacy-loggers, spacy-legacy, shellingham, pydantic-core, murmurhash, mdurl, idna, h11, cymem, confection, cloudpathlib, click, charset_normalizer, certifi, catalogue, blis, annotated-types, annotated-doc, srsly, smart-open, requests, pydantic, preshed, markdown-it-py, httpcore, anyio, thinc, rich, httpx, typer, weasel, spacy
#
#    -- -------------------------------------  2/37 [urllib3]
#    -- -------------------------------------  2/37 [urllib3]
#    ---- -----------------------------------  4/37 [tqdm]
#    ------ ---------------------------------  6/37 [spacy-legacy]
#    -------- -------------------------------  8/37 [pydantic-core]
#    ----------- ---------------------------- 11/37 [idna]
#    --------------- ------------------------ 14/37 [confection]
#    ----------------- ---------------------- 16/37 [click]
#    ------------------- -------------------- 18/37 [certifi]
#    --------------------- ------------------ 20/37 [blis]
#    ------------------------ --------------- 23/37 [srsly]
#    ------------------------ --------------- 23/37 [srsly]
#    ------------------------ --------------- 23/37 [srsly]
#    ------------------------- -------------- 24/37 [smart-open]
#    ---------------------------- ----------- 26/37 [pydantic]
#    ---------------------------- ----------- 26/37 [pydantic]
#    ---------------------------- ----------- 26/37 [pydantic]
#    ---------------------------- ----------- 26/37 [pydantic]
#    ----------------------------- ---------- 27/37 [preshed]
#    ------------------------------ --------- 28/37 [markdown-it-py]
#    ------------------------------- -------- 29/37 [httpcore]
#    -------------------------------- ------- 30/37 [anyio]
#    --------------------------------- ------ 31/37 [thinc]
#    --------------------------------- ------ 31/37 [thinc]
#    --------------------------------- ------ 31/37 [thinc]
#    --------------------------------- ------ 31/37 [thinc]
#    ---------------------------------- ----- 32/37 [rich]
#    ---------------------------------- ----- 32/37 [rich]
#    ---------------------------------- ----- 32/37 [rich]
#    ---------------------------------- ----- 32/37 [rich]
#    ------------------------------------ --- 34/37 [typer]
#    ------------------------------------- -- 35/37 [weasel]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    -------------------------------------- - 36/37 [spacy]
#    ---------------------------------------- 37/37 [spacy]
#
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.13.0 blis-1.3.3 catalogue-2.0.10 certifi-2026.4.22 charset_normalizer-3.4.7 click-8.3.3 cloudpathlib-0.23.0 confection-1.3.3 cymem-2.0.13 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.13 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.13 pydantic-2.13.3 pydantic-core-2.46.3 requests-2.33.1 rich-15.0.0 shellingham-1.5.4 smart-open-7.6.0 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 tqdm-4.67.3 typer-0.24.2 typing-inspection-0.4.2 urllib3-2.6.3 wasabi-1.1.3 weasel-1.0.0 wrapt-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy_transformers
# Out:
# Collecting spacy_transformers
#   Downloading spacy_transformers-1.4.0-cp310-cp310-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy_transformers) (3.8.14)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy_transformers) (2.2.6)
# Collecting transformers<4.53.3,>=3.4.0 (from spacy_transformers)
#   Using cached transformers-4.53.2-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: torch>=1.8.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy_transformers) (2.11.0+cpu)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy_transformers) (2.5.3)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy_transformers)
#   Downloading spacy_alignments-0.9.2-cp310-cp310-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (0.24.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (4.67.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.33.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (2.13.3)
# Requirement already satisfied: jinja2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (70.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from spacy<4.1.0,>=3.5.0->spacy_transformers) (26.0)
# Requirement already satisfied: typing_extensions<5.0,>=4.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from confection<2.0.0,>=1.3.2->spacy<4.1.0,>=3.5.0->spacy_transformers) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2026.4.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy<4.1.0,>=3.5.0->spacy_transformers) (1.3.3)
# Requirement already satisfied: colorama in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.4.6)
# Requirement already satisfied: filelock in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from transformers<4.53.3,>=3.4.0->spacy_transformers) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers<4.53.3,>=3.4.0->spacy_transformers)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting pyyaml>=5.1 (from transformers<4.53.3,>=3.4.0->spacy_transformers)
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers<4.53.3,>=3.4.0->spacy_transformers)
#   Downloading regex-2026.4.4-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<4.53.3,>=3.4.0->spacy_transformers)
#   Using cached tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<4.53.3,>=3.4.0->spacy_transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers<4.53.3,>=3.4.0->spacy_transformers) (2026.2.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (0.1.2)
# Requirement already satisfied: wrapt in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (2.1.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from torch>=1.8.0->spacy_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from torch>=1.8.0->spacy_transformers) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->spacy_transformers) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy<4.1.0,>=3.5.0->spacy_transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy_transformers) (3.0.3)
# Downloading spacy_transformers-1.4.0-cp310-cp310-win_amd64.whl (350 kB)
# Downloading spacy_alignments-0.9.2-cp310-cp310-win_amd64.whl (184 kB)
# Using cached transformers-4.53.2-py3-none-any.whl (10.8 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached tokenizers-0.21.4-cp39-abi3-win_amd64.whl (2.5 MB)
# Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Downloading regex-2026.4.4-cp310-cp310-win_amd64.whl (278 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: spacy-alignments, safetensors, regex, pyyaml, huggingface-hub, tokenizers, transformers, spacy_transformers
#
#    ---------- ----------------------------- 2/8 [regex]
#    -------------------- ------------------- 4/8 [huggingface-hub]
#    -------------------- ------------------- 4/8 [huggingface-hub]
#    -------------------- ------------------- 4/8 [huggingface-hub]
#    -------------------- ------------------- 4/8 [huggingface-hub]
#    -------------------- ------------------- 4/8 [huggingface-hub]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ------------------------------ --------- 6/8 [transformers]
#    ----------------------------------- ---- 7/8 [spacy_transformers]
#    ---------------------------------------- 8/8 [spacy_transformers]
#
# Successfully installed huggingface-hub-0.36.2 pyyaml-6.0.3 regex-2026.4.4 safetensors-0.7.0 spacy-alignments-0.9.2 spacy_transformers-1.4.0 tokenizers-0.21.4 transformers-4.53.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Preparing data by merging the json files and also garding only the the skill annotalions

# %%
import os
import json

def load_spacy_data(folder_path):
    training_data = []

    for file_name in os.listdir(folder_path):
        if not file_name.endswith(".json"):
            continue

        file_path = os.path.join(folder_path, file_name)

        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        text = data["text"]
        annotations = data["annotations"]

        entities = []

        for ann in annotations:
            start, end, label = ann

            # KEEP ONLY SKILLS
            if "SKILL" in label:
                # clean label if needed (optional)
                entities.append((start, end, "SKILL"))

        # skip empty samples (important!)
        if entities:
            training_data.append((text, {"entities": entities}))

    return training_data

# %%
folder_path = r"C:\Users\wiame\Desktop\career-platform\ml\cv_parser\ResumesJsonAnnotated"
data = load_spacy_data(folder_path)

print(data[0])
# Out:
# ('One97 Communications Limited \nData Scientist Jan 2019 to Till Date \nDetect important information from images and redact\nrequired fields. YOLO CNN Object-detection, OCR\nInsights, find anomaly or performance drop in all\npossible sub-space. \nPredict the Insurance claim probability. Estimate the\npremium amount to be charged\nB.Tech(Computer Science) from SGBAU university in\n2017. \nM.Tech (Computer Science Engineering) from Indian\nInstitute of Technology (IIT), Kanpur in 2019WORK EXPERIENCE\nEDUCATIONMACY WILLIAMS\nDATA SCIENTIST\nData Scientist working  on problems related to market research and customer analysis. I want to expand my arsenal of\napplication building and work on different kinds of problems. Looking for a role where I can work with a coordinative team\nand exchange knowledge during the process.\nJava, C++, Python, Machine Learning, Algorithms, Natural Language Processing, Deep Learning, Computer Vision, Pattern\nRecognition, Data Science, Data Analysis, Software Engineer, Data Analyst, C, PySpark, Kubeflow.ABOUT\nSKILLS\nCustomer browsing patterns.\nPredict potential RTO(Return To Origin) orders for e-\ncommerce.\nObject Detection.PROJECTS\nACTIVITES', {'entities': [(657, 665, 'SKILL'), (822, 828, 'SKILL'), (811, 815, 'SKILL'), (781, 790, 'SKILL'), (877, 887, 'SKILL'), (194, 205, 'SKILL'), (442, 452, 'SKILL'), (1007, 1014, 'SKILL'), (30, 44, 'SKILL'), (153, 162, 'SKILL'), (329, 345, 'SKILL'), (102, 108, 'SKILL'), (889, 902, 'SKILL'), (942, 954, 'SKILL'), (1031, 1037, 'SKILL'), (1147, 1155, 'SKILL'), (734, 737, 'SKILL'), (575, 590, 'SKILL'), (956, 969, 'SKILL'), (904, 919, 'SKILL'), (802, 809, 'SKILL'), (817, 818, 'SKILL'), (164, 167, 'SKILL'), (604, 612, 'SKILL'), (838, 846, 'SKILL'), (971, 988, 'SKILL'), (338, 345, 'SKILL'), (267, 278, 'SKILL'), (772, 780, 'SKILL'), (379, 380, 'SKILL'), (913, 919, 'SKILL'), (6, 20, 'SKILL'), (868, 887, 'SKILL'), (763, 767, 'SKILL'), (30, 34, 'SKILL'), (860, 887, 'SKILL'), (980, 988, 'SKILL'), (1130, 1146, 'SKILL'), (921, 928, 'SKILL'), (387, 415, 'SKILL'), (830, 846, 'SKILL'), (1016, 1024, 'SKILL'), (582, 590, 'SKILL'), (1056, 1064, 'SKILL'), (293, 300, 'SKILL'), (555, 563, 'SKILL'), (848, 858, 'SKILL'), (645, 656, 'SKILL'), (990, 1002, 'SKILL'), (860, 876, 'SKILL'), (168, 176, 'SKILL'), (995, 1002, 'SKILL'), (324, 328, 'SKILL'), (929, 940, 'SKILL'), (251, 260, 'SKILL'), (595, 603, 'SKILL'), (85, 96, 'SKILL'), (404, 415, 'SKILL'), (329, 337, 'SKILL'), (971, 979, 'SKILL'), (645, 665, 'SKILL'), (142, 145, 'SKILL'), (595, 612, 'SKILL'), (868, 876, 'SKILL'), (670, 674, 'SKILL'), (35, 44, 'SKILL'), (129, 135, 'SKILL'), (1084, 1087, 'SKILL'), (231, 236, 'SKILL'), (1120, 1128, 'SKILL')]})

# %%
import spacy 
from spacy.tokens import DocBin
from tqdm import tqdm
import json

# %%
spacy.__version__
# Out:
# '3.8.14'

# %%
# !nvidia-smi
# Out:
# Fri Apr 24 23:17:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.95                 Driver Version: 581.95         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX 500 Ada Gener...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   50C    P8              5W /   29W |     159MiB /   4094MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           15980    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           54392    C+G   ...Browser\Application\brave.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
len(data)
# Out:
# 4971

# %%
# !python -m spacy init fill-config C:\Users\wiame\Desktop\career-platform\ml\cv_parser\config\base_config.cfg C:\Users\wiame\Desktop\career-platform\ml\cv_parser\config\config.cfg
# Out:
# [+] Auto-filled config with all values
# [+] Saved config
# C:\Users\wiame\Desktop\career-platform\ml\cv_parser\config\config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# ## preparing the data to be in a spacy format

# %%
pip install ftfy
# Out:
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: wcwidth in c:\users\wiame\anaconda3\envs\cv-parser\lib\site-packages (from ftfy) (0.6.0)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_spacy_doc(file,data):
    nlp = spacy.blank("en")
    db = DocBin()

    for text,annot in tqdm(data):
        text = clean_text(text)
        doc = nlp.make_doc(text)
        annot = annot['entities']

        ents = []
        entity_indices = []

        for start,end,label in annot :
            skip_entity = False
            for idx in range(start,end):
                if idx in entity_indices:
                    skip_entity = True
                    break
            if skip_entity == True:
                continue

            entity_indices = entity_indices + list(range(start,end))

            try : 
                span = doc.char_span(start,end,label = label ,alignment_mode='strict')
            except :
                continue
            if span is None :
                err_data = str([start,end]) + "    " + str(text) + "\n"
                file.write(err_data)
            else :
                ents.append(span)
        try : 
            doc.ents = ents
            db.add(doc)
        except:
            pass
    return db

# %%
pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split 

train,test = train_test_split(data,test_size=0.3)

# %%
len(train),len(test)
# Out:
# (3479, 1492)

# %% [markdown]
# ### saving the train and test data

# %%
file = open(r'C:\Users\wiame\Desktop\career-platform\ml\cv_parser\model\train_file.txt', 'w', encoding='utf-8')

db = get_spacy_doc(file,train)
db.to_disk(r'C:\Users\wiame\Desktop\career-platform\ml\cv_parser\model\train_data.spacy')

db = get_spacy_doc(file,test)
db.to_disk(r'C:\Users\wiame\Desktop\career-platform\ml\cv_parser\model\test_data.spacy')

file.close()
# Out:
# 100%|██████████| 3479/3479 [02:37<00:00, 22.07it/s]
# 100%|██████████| 1492/1492 [01:07<00:00, 22.08it/s]

# %% [markdown]
# ### training the model

# %%
# !python -m spacy train "C:/Users/wiame/Desktop/career-platform/ml/cv_parser/config/config.cfg" --output "C:/Users/wiame/Desktop/career-platform/ml/cv_parser/model/output" --paths.train "C:/Users/wiame/Desktop/career-platform/ml/cv_parser/model/train_data.spacy" --paths.dev "C:/Users/wiame/Desktop/career-platform/ml/cv_parser/model/test_data.spacy"
